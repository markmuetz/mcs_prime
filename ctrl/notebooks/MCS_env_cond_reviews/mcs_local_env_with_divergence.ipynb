# %%
import numpy as np
import xarray as xr

from remake import load_remake

# %%
rmk = load_remake('../../mcs_env_cond_reviews_remakefiles/mcs_env_cond_figs.py').finalize()
# Out:
# => mcs_env_cond_figs <=

# %%
t = rmk.tasks[0]

# %%
t.inputs
# Out:
# {'mcs_local_env_2020_1': PosixPath('/gws/nopw/j04/mcs_prime/mmuetz/data/mcs_prime_output/mcs_local_envs/2020/01/lifecycle_mcs_local_env_2020_01.nc'),
#  'mcs_local_env_2020_2': PosixPath('/gws/nopw/j04/mcs_prime/mmuetz/data/mcs_prime_output/mcs_local_envs/2020/02/lifecycle_mcs_local_env_2020_02.nc'),
#  'var_mcs_local_env_2020_1_div_ml114': PosixPath('/gws/nopw/j04/mcs_prime/mmuetz/data/mcs_prime_output/mcs_env_cond_reviews/mcs_local_envs/2020/01/lifecycle_mcs_local_env_2020_01.div_ml114.nc'),
#  'var_mcs_local_env_2020_1_div_ml105': PosixPath('/gws/nopw/j04/mcs_prime/mmuetz/data/mcs_prime_output/mcs_env_cond_reviews/mcs_local_envs/2020/01/lifecycle_mcs_local_env_2020_01.div_ml105.nc'),
#  'var_mcs_local_env_2020_1_div_ml101': PosixPath('/gws/nopw/j04/mcs_prime/mmuetz/data/mcs_prime_output/mcs_env_cond_reviews/mcs_local_envs/2020/01/lifecycle_mcs_local_env_2020_01.div_ml101.nc'),
# ...

# %%
ds_full = xr.open_mfdataset(
    [t.inputs[f'mcs_local_env_2020_{m}'] for m in [1, 2]],
    combine='nested',
    concat_dim='tracks',
)

# %%
ds_var = xr.open_mfdataset(
    [t.inputs[f'var_mcs_local_env_2020_{m}_div_ml{l}'] for m in [1, 2] for l in [114, 105]],
    combine='nested',
    concat_dim='tracks',    
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/mcs_prime_env/lib/python3.10/site-packages/xarray/core/dataset.py:1394, in Dataset._construct_dataarray(self, name)
#    1393 try:
# -> 1394     variable = self._variables[name]
#    1395 except KeyError:
#
# KeyError: 'mean_div_ml114'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/mcs_prime_env/lib/python3.10/site-packages/xarray/core/concat.py:514, in _dataset_concat(datasets, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs)
#     513 try:
# --> 514     vars = ensure_common_dims([ds[k].variable for ds in datasets])
#     515 except KeyError:
#
# ...

# %%
ds = xr.open_mfdataset(
    [t.inputs[f'mcs_local_env_2020_{m}'] for m in [1, 2]] +
    [t.inputs[f'var_mcs_local_env_2020_{m}_div_ml{l}'] for m in [1, 2] for l in [114, 105]],
)

# %%
ds_full
# Out:
# <xarray.Dataset>
# Dimensions:                                             (tracks: 4588,
#                                                          radius: 5, times: 424,
#                                                          percentile: 5)
# Coordinates:
#   * tracks                                              (tracks) int64 0 ... ...
#   * radius                                              (radius) int64 1 ... ...
#   * times                                               (times) int64 -24 ......
#   * percentile                                          (percentile) int64 10...
# Data variables: (12/26)
#     mean_cape                                           (tracks, radius, times) float64 dask.array<chunksize=(2406, 5, 424), meta=np.ndarray>
#     percentile_cape                                     (tracks, radius, percentile, times) float64 dask.array<chunksize=(2406, 5, 5, 424), meta=np.ndarray>
# ...

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:                                             (tracks: 4588,
#                                                          radius: 5, times: 424,
#                                                          percentile: 5)
# Coordinates:
#   * tracks                                              (tracks) int64 0 ... ...
#   * radius                                              (radius) int64 1 ... ...
#   * times                                               (times) int64 -24 ......
#   * percentile                                          (percentile) int64 10...
# Data variables: (12/30)
#     mean_cape                                           (tracks, radius, times) float64 dask.array<chunksize=(2406, 5, 424), meta=np.ndarray>
#     percentile_cape                                     (tracks, radius, percentile, times) float64 dask.array<chunksize=(2406, 5, 5, 424), meta=np.ndarray>
# ...

# %%
nm = ~np.isnan(ds.mean_cape.values)
(ds.mean_cape.values[nm] == ds_full.mean_cape.values[nm]).all()
# Out:
# True
