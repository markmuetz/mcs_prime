# %% [markdown]
# # Example of loading shear/VIMFD over S Asia
#
# * ERA5 data but interpolated in time to on the half hour (to match MCS tracking)
# * Each hour of 2020 present.
# * New format for dataset - shear now has three top-level data variables - shear_0, shear_1, shear_2
# * I've included vertically integraded moisture flux divergence - essentially a measure of how much total moisture is converging (when negative) on a given grid cell.

# %%
import datetime as dt
from pathlib import Path

import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import xarray as xr

# %%
year = 2020
month = 1
day = 1
h = 0

e5time = pd.Timestamp(year, month, day, h, 0)

# %%
outdir = Path('/gws/nopw/j04/mcs_prime/mmuetz/data/mcs_prime_output') / 'regional_ERA5_data' / 'east_asia'/ f'{e5time.year}' / f'{e5time.month:02d}' / f'{e5time.day:02d}'
filename = f'ecmwf-era5_oper_an_sfc_{e5time.year}{e5time.month:02d}{e5time.day:02d}{e5time.hour:02d}30.shear_vimfd.east_asia.nc'
outpath = outdir / filename
print(outpath, outpath.exists())
# Out:
# /gws/nopw/j04/mcs_prime/mmuetz/data/mcs_prime_output/regional_ERA5_data/east_asia/2020/01/01/ecmwf-era5_oper_an_sfc_202001010030.shear_vimfd.east_asia.nc True

# %%
ds_shear_vimfd = xr.open_dataset(outpath)
ds_shear_vimfd
# Out:
# <xarray.Dataset>
# Dimensions:                                  (latitude: 221, longitude: 281)
# Coordinates:
#   * latitude                                 (latitude) float32 55.0 ... 0.0
#   * longitude                                (longitude) float32 95.0 ... 165.0
#     time                                     datetime64[ns] ...
# Data variables:
#     shear_0                                  (latitude, longitude) float64 ...
#     shear_1                                  (latitude, longitude) float64 ...
#     shear_2                                  (latitude, longitude) float64 ...
#     vertically_integrated_moisture_flux_div  (latitude, longitude) float64 ...
# Attributes:
#     shear_0:  LLS: shear between surf and 800 hPa (ERA5 136-111)
#     shear_1:  Low-to-mid: shear between 800 and 600 hPa (ERA5 111-101)
#     shear_2:  MLS: shear between surf and 600 hPa (ERA5 136-101)
