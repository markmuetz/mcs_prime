# %%
import os

from remake import load_remake

# %%
os.chdir('../../remakefiles')
tep = load_remake('track_era5_propagation_corr.py').finalize()
# Out:
# => track_era5_propagation_corr <=

# %%
tep
# Out:
# Remake[finalized=True, ntasks=367]

# %%
tep.tasks
# Out:
# [e55c799eb8 TrackERA5PropagationCorr(year=2019, month=1, day=1),
#  ba6d7a8da7 TrackERA5PropagationCorr(year=2019, month=1, day=2),
#  61f24e9c14 TrackERA5PropagationCorr(year=2019, month=1, day=3),
#  1f01ad9c2f TrackERA5PropagationCorr(year=2019, month=1, day=4),
#  7cf1088123 TrackERA5PropagationCorr(year=2019, month=1, day=5),
#  f084b57b50 TrackERA5PropagationCorr(year=2019, month=1, day=6),
#  a095cd55c7 TrackERA5PropagationCorr(year=2019, month=1, day=7),
#  44919cae75 TrackERA5PropagationCorr(year=2019, month=1, day=8),
#  99c4564230 TrackERA5PropagationCorr(year=2019, month=1, day=9),
#  0417b5ce8b TrackERA5PropagationCorr(year=2019, month=1, day=10),
#  61774679f8 TrackERA5PropagationCorr(year=2019, month=1, day=11),
#  37d7ae7bf1 TrackERA5PropagationCorr(year=2019, month=1, day=12),
#  f2b6b5a12d TrackERA5PropagationCorr(year=2019, month=1, day=13),
#  49f9d3b250 TrackERA5PropagationCorr(year=2019, month=1, day=14),
# ...

# %%
tep.tasks.status()
# Out:
# e55c79: completed  - e55c799eb8 TrackERA5PropagationCorr(year=2019, month=1, day=1)
# ba6d7a: completed  - ba6d7a8da7 TrackERA5PropagationCorr(year=2019, month=1, day=2)
# 61f24e: completed  - 61f24e9c14 TrackERA5PropagationCorr(year=2019, month=1, day=3)
# 1f01ad: completed  - 1f01ad9c2f TrackERA5PropagationCorr(year=2019, month=1, day=4)
# 7cf108: completed  - 7cf1088123 TrackERA5PropagationCorr(year=2019, month=1, day=5)
# f084b5: completed  - f084b57b50 TrackERA5PropagationCorr(year=2019, month=1, day=6)
# a095cd: completed  - a095cd55c7 TrackERA5PropagationCorr(year=2019, month=1, day=7)
# 44919c: completed  - 44919cae75 TrackERA5PropagationCorr(year=2019, month=1, day=8)
# 99c456: completed  - 99c4564230 TrackERA5PropagationCorr(year=2019, month=1, day=9)
# 0417b5: completed  - 0417b5ce8b TrackERA5PropagationCorr(year=2019, month=1, day=10)
# 617746: pending    - 61774679f8 TrackERA5PropagationCorr(year=2019, month=1, day=11)
# ...
