# %% [markdown]
# # Figure out how to quickly round times using np ops
#
# I.e. not using Python for loops or vectoriziation.
#
# * Archive.

# %%
import numpy as np
import xarray as xr
from mcs_prime import McsTracks
from mcs_prime.mcs_prime_config import PATHS

# %%
tracks = McsTracks.mfload()

# %%
tracks.dstracks
# Out:
# <xarray.Dataset>
# Dimensions:                  (tracks: 696293, times: 400, mergers: 50, nmaxpf: 3)
# Coordinates:
#   * tracks                   (tracks) int64 0 1 2 3 ... 696290 696291 696292
#   * times                    (times) int64 0 1 2 3 4 5 ... 395 396 397 398 399
#   * mergers                  (mergers) int64 0 1 2 3 4 5 6 ... 44 45 46 47 48 49
#   * nmaxpf                   (nmaxpf) int64 0 1 2
# Data variables: (12/55)
#     track_duration           (tracks) int32 dask.array<chunksize=(21142,), meta=np.ndarray>
#     start_status             (tracks) int32 dask.array<chunksize=(21142,), meta=np.ndarray>
#     end_status               (tracks) int32 dask.array<chunksize=(21142,), meta=np.ndarray>
#     start_basetime           (tracks) datetime64[ns] 2000-06-01T00:30:00 ... ...
#     end_basetime             (tracks) datetime64[ns] 2000-06-01T12:30:00 ... ...
#     start_split_cloudnumber  (tracks) int32 dask.array<chunksize=(21142,), meta=np.ndarray>
# ...

# %%
tracks.dstracks.base_time.values[0]
# Out:
# array(['2000-06-01T00:30:00.000000000', '2000-06-01T01:30:00.000000000',
#        '2000-06-01T02:30:00.000000000', '2000-06-01T03:30:00.000000000',
#        '2000-06-01T04:30:00.000000000', '2000-06-01T05:30:00.000000000',
#        '2000-06-01T06:30:00.000000000', '2000-06-01T07:30:00.000000000',
#        '2000-06-01T08:30:00.000000000', '2000-06-01T09:30:00.000000000',
#        '2000-06-01T10:30:00.000000000', '2000-06-01T11:30:00.000000000',
#        '2000-06-01T12:30:00.000000000', '1969-12-31T21:13:21.000000000',
#        '1969-12-31T21:13:21.000000000', '1969-12-31T21:13:21.000000000',
#        '1969-12-31T21:13:21.000000000', '1969-12-31T21:13:21.000000000',
#        '1969-12-31T21:13:21.000000000', '1969-12-31T21:13:21.000000000',
#        '1969-12-31T21:13:21.000000000', '1969-12-31T21:13:21.000000000',
#        '1969-12-31T21:13:21.000000000', '1969-12-31T21:13:21.000000000',
#        '1969-12-31T21:13:21.000000000', '1969-12-31T21:13:21.000000000',
# ...

# %%
tmask = ~np.isnan(tracks.dstracks.base_time.values)
np.array(tracks.dstracks.base_time.values[tmask].astype(int), dtype='datetime64[ns]')
# Out:
# array(['2019-01-01T00:30:00.000013312', '2019-01-01T01:30:00.000000000',
#        '2019-01-01T02:30:00.000026880', ...,
#        '2019-12-31T20:30:00.000026880', '2019-12-31T21:30:00.000013312',
#        '2019-12-31T22:30:00.000000000'], dtype='datetime64[ns]')

# %%
ivals = tracks.dstracks.base_time.values[tmask].astype(int)

# %%
ivals
# Out:
# array([1546302600000013312, 1546306200000000000, 1546309800000026880, ...,
#        1577824200000026880, 1577827800000013312, 1577831400000000000])

# %%
# Note, using string as the type, with [ns] (nanoseconds) fixed this for me.
(np.round(ivals / 1e9) * 1e9).astype('datetime64[ns]')
# Out:
# array(['2019-01-01T00:30:00.000000000', '2019-01-01T01:30:00.000000000',
#        '2019-01-01T02:30:00.000000000', ...,
#        '2019-12-31T20:30:00.000000000', '2019-12-31T21:30:00.000000000',
#        '2019-12-31T22:30:00.000000000'], dtype='datetime64[ns]')
