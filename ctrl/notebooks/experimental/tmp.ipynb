# %%
class LoopPercentageDisp:
    def __init__(self, L, step_percentage=10, fmt='{percentage:.1f}% ({i}/{L})'):
        self.L = L
        self.step_percentage = step_percentage
        self.disp_percentage = step_percentage
        self.fmt = fmt
        self.curr_percentage = 0

    def __call__(self, i):
        L = self.L
        percentage = i / L * 100
        if percentage >= self.disp_percentage:
            print(self.fmt.format(percentage=percentage, i=i, L=L))
            self.disp_percentage += self.step_percentage
        self.curr_percentage = percentage

# %%
L = 333
ld = LoopPercentageDisp(L, 20)
for i in range(L):
    ld(i)
# Out:
# 20.1% (67/333)
# 40.2% (134/333)
# 60.1% (200/333)
# 80.2% (267/333)

# %%
'{a}'.format(a=1, b=2)
# Out:
# '1'

# %%
import numpy as np

# %%
# a1 = np.random.random(int(200e6))
a1 = np.random.random(int(1e3))

# %%
#idx = np.sort(np.random.choice(np.arange(len(a1)), int(1e6), replace=False))

#len(np.unique(idx)) == len(idx)

# %%
#a1[idx]

# %%
24 * 12 * 144 * 48
# Out:
# 1990656

# %%
x = np.random.normal(size=int(1e6))
y = np.random.normal(size=int(1e6))

# %%
import seaborn as sns

# %%
# sns.scatterplot(x=x, y=y)
idx = np.sort(np.random.choice(np.arange(len(x)), int(1e4), replace=False))

# %%
# %%timeit
sns.kdeplot(x=x[idx], y=y[idx], color='black', levels=[0.01])
# Out:
# 6.08 s ± 122 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
sns.displot(x=x[idx[, y=y[idx], kind='kde', color='black', levels=[0.01])
# Out:
# Traceback (most recent call last):
#
#   File ~/miniconda3/envs/mcs_prime_env/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3369 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Input In [13] in <cell line: 1>
#     get_ipython().run_cell_magic('timeit', '', "sns.displot(x=x[idx[, y=y[idx], kind='kde', color='black', levels=[0.01])\n")
#
#   File ~/miniconda3/envs/mcs_prime_env/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2347 in run_cell_magic
#     result = fn(*args, **kwargs)
#
#   File ~/miniconda3/envs/mcs_prime_env/lib/python3.10/site-packages/IPython/core/magics/execution.py:1108 in timeit
#     ast_stmt = self.shell.compile.ast_parse(transform(cell))
#
#   File ~/miniconda3/envs/mcs_prime_env/lib/python3.10/site-packages/IPython/core/compilerop.py:105 in ast_parse
#     return compile(source, filename, symbol, self.flags | PyCF_ONLY_AST, 1)
#
#   File <unknown>:1
#     sns.displot(x=x[idx[, y=y[idx], kind='kde', color='black', levels=[0.01])
#                                                                             ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '['

# %%
import textwrap

# %%
level = 3
print(textwrap.indent('indented text\nwith linebreaks', level * '    '))
# Out:
#             indented text
#             with linebreaks

# %%
import matplotlib.pyplot as plt

# %%
fig, axes = plt.subplots(3, 3, layout='constrained')
for ax in axes.flatten()[[1, 2]]:
    ax.axis('off')
for ax in axes.flatten()[[0, 3, 4, 5, 6, 7, 8]]:
    ax.plot([1, 2, 4])

# %%
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import numpy as np

fig, axes = plt.subplots(2, 2, layout='constrained', subplot_kw={'projection': ccrs.PlateCarree()})
fig.set_size_inches(11, 5)
lon = np.linspace(-180, 180, 361)
lat = np.linspace(-90, 90, 181)
for ax in axes.flatten():
    im = ax.pcolormesh(lon, lat, np.random.random((181, 361)), vmin=0, vmax=1)
    ax.coastlines()

plt.colorbar(im, ax=axes)
