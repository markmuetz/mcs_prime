# %%
import xarray as xr

# %%
df_cf = xr.open_dataset('/gws/nopw/j04/mcs_prime/mmuetz/data/UM_sims/u-dg040/dg040a.pa1988sep.cf.nc')

# %%
df_cf.UM_m01s00i024_vn1300
# Out:
# <xarray.DataArray 'UM_m01s00i024_vn1300' (time: 30, latitude: 144,
#                                           longitude: 192)>
# [829440 values with dtype=float32]
# Coordinates:
#   * time       (time) object 1988-09-01 12:00:00 ... 1988-09-30 12:00:00
#   * latitude   (latitude) float64 -89.38 -88.12 -86.88 ... 86.88 88.12 89.38
#   * longitude  (longitude) float64 0.9375 2.812 4.688 ... 355.3 357.2 359.1
# Attributes:
#     long_name:        SURFACE TEMPERATURE AFTER TIMESTEP
#     um_stash_source:  m01s00i024
#     runid:            aaaaa
#     lbproc:           128
#     lbtim:            122
#     stash_code:       24
#     submodel:         1
#     standard_name:    surface_temperature
#     units:            K
#     cell_methods:     time: mean

# %%
df_iris = xr.open_dataset('/gws/nopw/j04/mcs_prime/mmuetz/data/UM_sims/u-dg040/dg040a.pa1988sep.iris.nc')

# %%
df_iris
# Out:
# <xarray.Dataset>
# Dimensions:                                (time: 30, latitude: 180,
#                                             longitude: 360, bnds: 2,
#                                             pressure: 2, latitude_0: 145,
#                                             longitude_0: 192, latitude_1: 144,
#                                             longitude_1: 192,
#                                             model_level_number: 52)
# Coordinates: (12/15)
#   * time                                   (time) object 1988-09-01 12:00:00 ...
#   * latitude                               (latitude) float32 -89.5 ... 89.5
#   * longitude                              (longitude) float32 0.5 1.5 ... 359.5
#     forecast_period                        (time) timedelta64[ns] ...
#     forecast_reference_time                object ...
#   * pressure                               (pressure) float32 200.0 850.0
#     ...                                     ...
# ...

# %%
df_iris.surface_temperature
# Out:
# <xarray.DataArray 'surface_temperature' (time: 30, latitude_1: 144,
#                                          longitude_1: 192)>
# [829440 values with dtype=float32]
# Coordinates:
#   * time                     (time) object 1988-09-01 12:00:00 ... 1988-09-30...
#     forecast_period          (time) timedelta64[ns] 0 days 12:00:00 ... 29 da...
#     forecast_reference_time  object 1988-09-01 00:00:00
#   * latitude_1               (latitude_1) float32 -89.38 -88.12 ... 88.12 89.38
#   * longitude_1              (longitude_1) float32 0.9375 2.812 ... 357.2 359.1
# Attributes:
#     standard_name:    surface_temperature
#     units:            K
#     um_stash_source:  m01s00i024
#     cell_methods:     time: mean (interval: 1 hour)
#     grid_mapping:     latitude_longitude
